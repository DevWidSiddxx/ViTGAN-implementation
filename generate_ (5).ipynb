# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from google.colab import drive
from PIL import Image
import time

# ========== SETUP ========== #
# Mount Google Drive
drive.flush_and_unmount()
drive.mount('/content/drive', force_remount=True)

# Configuration
dataset_path = "/content/drive/MyDrive/dfu /PartB_DFU_Dataset/Infection/Aug-Negative"  # UPDATE THIS
save_path = "/content/drive/MyDrive/ViTGAN_outputs"         # UPDATE THIS
os.makedirs(save_path, exist_ok=True)

# Hyperparameters
img_size = 64
channels = 3
latent_dim = 128
batch_size = 64
epochs = 500
save_interval = 25

# ========== DATA PIPELINE ========== #
def load_dataset(dataset_path, img_size):
    """Optimized data loading pipeline"""
    image_paths = [os.path.join(dataset_path, f) for f in os.listdir(dataset_path)
                  if f.endswith(('.jpg', '.jpeg', '.png'))]

    def preprocess_image(img_path):
        img = tf.io.read_file(img_path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [img_size, img_size])
        img = (img - 127.5) / 127.5  # Normalize to [-1, 1]
        return img

    dataset = tf.data.Dataset.from_tensor_slices(image_paths)
    dataset = dataset.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(2000).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset

dataset = load_dataset(dataset_path, img_size)

# ========== MODEL ARCHITECTURE ========== #
def build_generator(latent_dim):
    inputs = layers.Input(shape=(latent_dim,))

    # Foundation
    x = layers.Dense(8*8*256)(inputs)
    x = layers.Reshape((8, 8, 256))(x)

    # Upsampling blocks
    x = layers.Conv2DTranspose(128, 4, 2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(0.2)(x)

    x = layers.Conv2DTranspose(64, 4, 2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(0.2)(x)

    # Output (ensure exact dimensions)
    x = layers.Conv2DTranspose(channels, 4, padding='same', activation='tanh')(x)
    x = layers.Cropping2D(((0,1),(0,1)))(x) if img_size % 2 != 0 else x
    x = layers.Resizing(img_size, img_size)(x)

    return keras.Model(inputs, x, name="generator")

def build_discriminator():
    inputs = layers.Input(shape=(img_size, img_size, channels))

    # Downsampling blocks
    x = layers.Conv2D(64, 4, 2, padding='same')(inputs)
    x = layers.LeakyReLU(0.2)(x)

    x = layers.Conv2D(128, 4, 2, padding='same')(x)
    x = layers.LeakyReLU(0.2)(x)

    # Classification
    x = layers.Flatten()(x)
    x = layers.Dense(1)(x)

    return keras.Model(inputs, x, name="discriminator")

# ========== TRAINING SETUP ========== #
# Initialize models
generator = build_generator(latent_dim)
discriminator = build_discriminator()

# Optimizers
g_optimizer = Adam(0.0002, beta_1=0.5)
d_optimizer = Adam(0.0002, beta_1=0.5)

# Loss function
cross_entropy = keras.losses.BinaryCrossentropy(from_logits=True)

# ========== TRAINING LOOP ========== #
@tf.function
def train_step(real_images):
    # Train discriminator
    noise = tf.random.normal([batch_size, latent_dim])
    with tf.GradientTape() as d_tape:
        generated_images = generator(noise, training=True)
        real_output = discriminator(real_images, training=True)
        fake_output = discriminator(generated_images, training=True)
        d_loss = (cross_entropy(tf.ones_like(real_output), real_output) +
                 cross_entropy(tf.zeros_like(fake_output), fake_output)) / 2

    d_gradients = d_tape.gradient(d_loss, discriminator.trainable_variables)
    d_optimizer.apply_gradients(zip(d_gradients, discriminator.trainable_variables))

    # Train generator
    noise = tf.random.normal([batch_size, latent_dim])
    with tf.GradientTape() as g_tape:
        generated_images = generator(noise, training=True)
        fake_output = discriminator(generated_images, training=True)
        g_loss = cross_entropy(tf.ones_like(fake_output), fake_output)

    g_gradients = g_tape.gradient(g_loss, generator.trainable_variables)
    g_optimizer.apply_gradients(zip(g_gradients, generator.trainable_variables))

    return d_loss, g_loss

def save_images(epoch):
    """Save grid and individual images to Drive"""
    os.makedirs(save_path, exist_ok=True)
    noise = tf.random.normal([25, latent_dim])
    images = generator(noise, training=False)
    images = (images * 127.5 + 127.5).numpy().astype('uint8')

    # Save grid
    plt.figure(figsize=(10,10))
    for i in range(25):
        plt.subplot(5, 5, i+1)
        plt.imshow(images[i])
        plt.axis('off')
    plt.savefig(f"{save_path}/grid_{epoch:04d}.png")
    plt.close()

    # Save individual images
    for i, img in enumerate(images):
        Image.fromarray(img).save(f"{save_path}/img_{epoch:04d}_{i:02d}.png")

    print(f"✅ Saved outputs to {save_path}")

def train(dataset, epochs, save_interval):
    for epoch in range(epochs):
        start = time.time()

        total_d_loss = 0
        total_g_loss = 0
        num_batches = 0

        for batch in dataset:
            d_loss, g_loss = train_step(batch)
            total_d_loss += d_loss
            total_g_loss += g_loss
            num_batches += 1

        # Save progress
        if epoch % save_interval == 0 or epoch == epochs - 1:
            save_images(epoch)

        print(f"⏱️ Epoch {epoch+1}/{epochs} | "
              f"Disc Loss: {total_d_loss/num_batches:.4f} | "
              f"Gen Loss: {total_g_loss/num_batches:.4f} | "
              f"Time: {time.time()-start:.2f}s")

# ========== START TRAINING ========== #
print("🚀 Training started - monitoring progress...")
train(dataset, epochs, save_interval)

# Final save
generator.save(f"{save_path}/final_generator.h5")
print(f"🎉 Training complete! Models saved to {save_path}")
# Out:
# Mounted at /content/drive
# 🚀 Training started - monitoring progress...
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 1/500 | Disc Loss: 0.5914 | Gen Loss: 1.3614 | Time: 95.43s
# ⏱️ Epoch 2/500 | Disc Loss: 0.3521 | Gen Loss: 2.2827 | Time: 10.56s
# ⏱️ Epoch 3/500 | Disc Loss: 0.6712 | Gen Loss: 0.7224 | Time: 8.23s
# ⏱️ Epoch 4/500 | Disc Loss: 0.6246 | Gen Loss: 0.8602 | Time: 9.22s
# ⏱️ Epoch 5/500 | Disc Loss: 0.7118 | Gen Loss: 0.7818 | Time: 9.42s
# ⏱️ Epoch 6/500 | Disc Loss: 0.7035 | Gen Loss: 0.8148 | Time: 8.53s
# ⏱️ Epoch 7/500 | Disc Loss: 0.7060 | Gen Loss: 0.7119 | Time: 9.22s
# ⏱️ Epoch 8/500 | Disc Loss: 0.6978 | Gen Loss: 0.7704 | Time: 9.42s
# ⏱️ Epoch 9/500 | Disc Loss: 0.6950 | Gen Loss: 0.7112 | Time: 8.70s
# ⏱️ Epoch 10/500 | Disc Loss: 0.6931 | Gen Loss: 0.7573 | Time: 8.92s
# ⏱️ Epoch 11/500 | Disc Loss: 0.6961 | Gen Loss: 0.6995 | Time: 9.59s
# ⏱️ Epoch 12/500 | Disc Loss: 0.6928 | Gen Loss: 0.7218 | Time: 9.17s
# ⏱️ Epoch 13/500 | Disc Loss: 0.6953 | Gen Loss: 0.7195 | Time: 8.85s
# ⏱️ Epoch 14/500 | Disc Loss: 0.6928 | Gen Loss: 0.7044 | Time: 9.13s
# ⏱️ Epoch 15/500 | Disc Loss: 0.6895 | Gen Loss: 0.7341 | Time: 8.99s
# ⏱️ Epoch 16/500 | Disc Loss: 0.6946 | Gen Loss: 0.6903 | Time: 8.58s
# ⏱️ Epoch 17/500 | Disc Loss: 0.6884 | Gen Loss: 0.7407 | Time: 9.63s
# ⏱️ Epoch 18/500 | Disc Loss: 0.6922 | Gen Loss: 0.6912 | Time: 9.37s
# ⏱️ Epoch 19/500 | Disc Loss: 0.6884 | Gen Loss: 0.7248 | Time: 8.53s
# ⏱️ Epoch 20/500 | Disc Loss: 0.6915 | Gen Loss: 0.7053 | Time: 9.04s
# ⏱️ Epoch 21/500 | Disc Loss: 0.6901 | Gen Loss: 0.7417 | Time: 9.33s
# ⏱️ Epoch 22/500 | Disc Loss: 0.6906 | Gen Loss: 0.7169 | Time: 8.78s
# ⏱️ Epoch 23/500 | Disc Loss: 0.6925 | Gen Loss: 0.7060 | Time: 9.22s
# ⏱️ Epoch 24/500 | Disc Loss: 0.6942 | Gen Loss: 0.7418 | Time: 9.43s
# ⏱️ Epoch 25/500 | Disc Loss: 0.6873 | Gen Loss: 0.7269 | Time: 8.95s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 26/500 | Disc Loss: 0.6836 | Gen Loss: 0.7229 | Time: 9.53s
# ⏱️ Epoch 27/500 | Disc Loss: 0.6902 | Gen Loss: 0.7340 | Time: 9.47s
# ⏱️ Epoch 28/500 | Disc Loss: 0.6884 | Gen Loss: 0.7209 | Time: 9.63s
# ⏱️ Epoch 29/500 | Disc Loss: 0.6872 | Gen Loss: 0.7304 | Time: 8.82s
# ⏱️ Epoch 30/500 | Disc Loss: 0.6906 | Gen Loss: 0.7404 | Time: 9.18s
# ⏱️ Epoch 31/500 | Disc Loss: 0.6894 | Gen Loss: 0.7131 | Time: 9.30s
# ⏱️ Epoch 32/500 | Disc Loss: 0.6869 | Gen Loss: 0.7396 | Time: 8.62s
# ⏱️ Epoch 33/500 | Disc Loss: 0.6880 | Gen Loss: 0.7421 | Time: 8.90s
# ⏱️ Epoch 34/500 | Disc Loss: 0.6872 | Gen Loss: 0.7394 | Time: 9.15s
# ⏱️ Epoch 35/500 | Disc Loss: 0.6905 | Gen Loss: 0.7324 | Time: 8.77s
# ⏱️ Epoch 36/500 | Disc Loss: 0.6909 | Gen Loss: 0.7265 | Time: 8.68s
# ⏱️ Epoch 37/500 | Disc Loss: 0.6871 | Gen Loss: 0.7335 | Time: 9.11s
# ⏱️ Epoch 38/500 | Disc Loss: 0.6852 | Gen Loss: 0.7280 | Time: 8.69s
# ⏱️ Epoch 39/500 | Disc Loss: 0.6846 | Gen Loss: 0.7640 | Time: 8.55s
# ⏱️ Epoch 40/500 | Disc Loss: 0.6834 | Gen Loss: 0.7589 | Time: 9.06s
# ⏱️ Epoch 41/500 | Disc Loss: 0.6843 | Gen Loss: 0.7436 | Time: 8.76s
# ⏱️ Epoch 42/500 | Disc Loss: 0.6791 | Gen Loss: 0.7547 | Time: 8.45s
# ⏱️ Epoch 43/500 | Disc Loss: 0.6758 | Gen Loss: 0.7668 | Time: 9.13s
# ⏱️ Epoch 44/500 | Disc Loss: 0.6835 | Gen Loss: 0.7521 | Time: 8.84s
# ⏱️ Epoch 45/500 | Disc Loss: 0.6792 | Gen Loss: 0.7552 | Time: 8.26s
# ⏱️ Epoch 46/500 | Disc Loss: 0.6692 | Gen Loss: 0.8097 | Time: 9.04s
# ⏱️ Epoch 47/500 | Disc Loss: 0.6732 | Gen Loss: 0.8146 | Time: 10.22s
# ⏱️ Epoch 48/500 | Disc Loss: 0.6753 | Gen Loss: 0.7836 | Time: 8.32s
# ⏱️ Epoch 49/500 | Disc Loss: 0.6698 | Gen Loss: 0.8210 | Time: 9.20s
# ⏱️ Epoch 50/500 | Disc Loss: 0.6649 | Gen Loss: 0.8348 | Time: 9.24s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 51/500 | Disc Loss: 0.6567 | Gen Loss: 0.8605 | Time: 9.16s
# ⏱️ Epoch 52/500 | Disc Loss: 0.6355 | Gen Loss: 0.9070 | Time: 8.68s
# ⏱️ Epoch 53/500 | Disc Loss: 0.6524 | Gen Loss: 0.8719 | Time: 9.11s
# ⏱️ Epoch 54/500 | Disc Loss: 0.6395 | Gen Loss: 0.8949 | Time: 10.22s
# ⏱️ Epoch 55/500 | Disc Loss: 0.6330 | Gen Loss: 0.9742 | Time: 8.26s
# ⏱️ Epoch 56/500 | Disc Loss: 0.6020 | Gen Loss: 0.9160 | Time: 8.94s
# ⏱️ Epoch 57/500 | Disc Loss: 0.6141 | Gen Loss: 0.9721 | Time: 8.88s
# ⏱️ Epoch 58/500 | Disc Loss: 0.5968 | Gen Loss: 0.9438 | Time: 8.32s
# ⏱️ Epoch 59/500 | Disc Loss: 0.5756 | Gen Loss: 0.9948 | Time: 8.95s
# ⏱️ Epoch 60/500 | Disc Loss: 0.5712 | Gen Loss: 1.0161 | Time: 9.27s
# ⏱️ Epoch 61/500 | Disc Loss: 0.5310 | Gen Loss: 1.0632 | Time: 8.66s
# ⏱️ Epoch 62/500 | Disc Loss: 0.5052 | Gen Loss: 1.1240 | Time: 9.22s
# ⏱️ Epoch 63/500 | Disc Loss: 0.4695 | Gen Loss: 1.2194 | Time: 9.28s
# ⏱️ Epoch 64/500 | Disc Loss: 0.4175 | Gen Loss: 1.3470 | Time: 8.36s
# ⏱️ Epoch 65/500 | Disc Loss: 0.3983 | Gen Loss: 1.3259 | Time: 8.96s
# ⏱️ Epoch 66/500 | Disc Loss: 0.3323 | Gen Loss: 1.4946 | Time: 9.25s
# ⏱️ Epoch 67/500 | Disc Loss: 0.2909 | Gen Loss: 1.6386 | Time: 8.20s
# ⏱️ Epoch 68/500 | Disc Loss: 0.2739 | Gen Loss: 1.6788 | Time: 8.94s
# ⏱️ Epoch 69/500 | Disc Loss: 0.2371 | Gen Loss: 1.8343 | Time: 9.15s
# ⏱️ Epoch 70/500 | Disc Loss: 0.1969 | Gen Loss: 1.9773 | Time: 8.47s
# ⏱️ Epoch 71/500 | Disc Loss: 0.1922 | Gen Loss: 2.0770 | Time: 9.01s
# ⏱️ Epoch 72/500 | Disc Loss: 0.1422 | Gen Loss: 2.2794 | Time: 9.27s
# ⏱️ Epoch 73/500 | Disc Loss: 0.1711 | Gen Loss: 2.1789 | Time: 8.69s
# ⏱️ Epoch 74/500 | Disc Loss: 0.1295 | Gen Loss: 2.3860 | Time: 9.11s
# ⏱️ Epoch 75/500 | Disc Loss: 0.1117 | Gen Loss: 2.4959 | Time: 9.33s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 76/500 | Disc Loss: 0.1853 | Gen Loss: 2.4030 | Time: 10.06s
# ⏱️ Epoch 77/500 | Disc Loss: 0.1211 | Gen Loss: 2.5254 | Time: 8.54s
# ⏱️ Epoch 78/500 | Disc Loss: 0.0974 | Gen Loss: 2.7003 | Time: 9.28s
# ⏱️ Epoch 79/500 | Disc Loss: 0.0833 | Gen Loss: 2.7880 | Time: 9.15s
# ⏱️ Epoch 80/500 | Disc Loss: 0.0771 | Gen Loss: 2.8613 | Time: 8.36s
# ⏱️ Epoch 81/500 | Disc Loss: 0.0694 | Gen Loss: 2.9037 | Time: 8.92s
# ⏱️ Epoch 82/500 | Disc Loss: 0.0680 | Gen Loss: 2.9818 | Time: 8.98s
# ⏱️ Epoch 83/500 | Disc Loss: 0.0600 | Gen Loss: 3.0786 | Time: 8.33s
# ⏱️ Epoch 84/500 | Disc Loss: 0.0632 | Gen Loss: 3.1541 | Time: 9.02s
# ⏱️ Epoch 85/500 | Disc Loss: 0.0570 | Gen Loss: 3.1443 | Time: 8.89s
# ⏱️ Epoch 86/500 | Disc Loss: 0.0551 | Gen Loss: 3.2058 | Time: 8.47s
# ⏱️ Epoch 87/500 | Disc Loss: 0.0509 | Gen Loss: 3.2479 | Time: 9.10s
# ⏱️ Epoch 88/500 | Disc Loss: 0.2777 | Gen Loss: 2.8626 | Time: 9.37s
# ⏱️ Epoch 89/500 | Disc Loss: 0.0669 | Gen Loss: 2.8268 | Time: 8.68s
# ⏱️ Epoch 90/500 | Disc Loss: 0.0521 | Gen Loss: 3.1399 | Time: 9.13s
# ⏱️ Epoch 91/500 | Disc Loss: 0.0460 | Gen Loss: 3.2678 | Time: 9.21s
# ⏱️ Epoch 92/500 | Disc Loss: 0.0445 | Gen Loss: 3.3783 | Time: 8.67s
# ⏱️ Epoch 93/500 | Disc Loss: 0.0390 | Gen Loss: 3.4616 | Time: 9.03s
# ⏱️ Epoch 94/500 | Disc Loss: 0.0377 | Gen Loss: 3.4894 | Time: 9.11s
# ⏱️ Epoch 95/500 | Disc Loss: 0.0360 | Gen Loss: 3.5699 | Time: 8.29s
# ⏱️ Epoch 96/500 | Disc Loss: 0.0340 | Gen Loss: 3.6286 | Time: 8.61s
# ⏱️ Epoch 97/500 | Disc Loss: 0.0316 | Gen Loss: 3.7050 | Time: 9.97s
# ⏱️ Epoch 98/500 | Disc Loss: 0.0308 | Gen Loss: 3.7810 | Time: 8.72s
# ⏱️ Epoch 99/500 | Disc Loss: 0.0307 | Gen Loss: 3.8341 | Time: 8.51s
# ⏱️ Epoch 100/500 | Disc Loss: 0.0285 | Gen Loss: 3.8573 | Time: 9.07s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 101/500 | Disc Loss: 0.0257 | Gen Loss: 3.9010 | Time: 9.83s
# ⏱️ Epoch 102/500 | Disc Loss: 0.0253 | Gen Loss: 3.9870 | Time: 8.32s
# ⏱️ Epoch 103/500 | Disc Loss: 0.0271 | Gen Loss: 3.9573 | Time: 9.12s
# ⏱️ Epoch 104/500 | Disc Loss: 0.0447 | Gen Loss: 3.8290 | Time: 9.06s
# ⏱️ Epoch 105/500 | Disc Loss: 0.0227 | Gen Loss: 3.9964 | Time: 8.26s
# ⏱️ Epoch 106/500 | Disc Loss: 0.0277 | Gen Loss: 4.0102 | Time: 9.10s
# ⏱️ Epoch 107/500 | Disc Loss: 0.2254 | Gen Loss: 3.5519 | Time: 8.84s
# ⏱️ Epoch 108/500 | Disc Loss: 0.0441 | Gen Loss: 3.2565 | Time: 8.15s
# ⏱️ Epoch 109/500 | Disc Loss: 0.0319 | Gen Loss: 3.5582 | Time: 8.91s
# ⏱️ Epoch 110/500 | Disc Loss: 0.0263 | Gen Loss: 3.7796 | Time: 8.92s
# ⏱️ Epoch 111/500 | Disc Loss: 0.0242 | Gen Loss: 3.9193 | Time: 8.14s
# ⏱️ Epoch 112/500 | Disc Loss: 0.0218 | Gen Loss: 3.9967 | Time: 8.91s
# ⏱️ Epoch 113/500 | Disc Loss: 0.0211 | Gen Loss: 4.0822 | Time: 8.83s
# ⏱️ Epoch 114/500 | Disc Loss: 0.0191 | Gen Loss: 4.1912 | Time: 8.24s
# ⏱️ Epoch 115/500 | Disc Loss: 0.0182 | Gen Loss: 4.2408 | Time: 8.94s
# ⏱️ Epoch 116/500 | Disc Loss: 0.0174 | Gen Loss: 4.3227 | Time: 8.53s
# ⏱️ Epoch 117/500 | Disc Loss: 0.0172 | Gen Loss: 4.3612 | Time: 8.13s
# ⏱️ Epoch 118/500 | Disc Loss: 0.0153 | Gen Loss: 4.3733 | Time: 9.13s
# ⏱️ Epoch 119/500 | Disc Loss: 0.0147 | Gen Loss: 4.4697 | Time: 8.84s
# ⏱️ Epoch 120/500 | Disc Loss: 0.0147 | Gen Loss: 4.4229 | Time: 8.44s
# ⏱️ Epoch 121/500 | Disc Loss: 0.0157 | Gen Loss: 4.4430 | Time: 9.11s
# ⏱️ Epoch 122/500 | Disc Loss: 0.1206 | Gen Loss: 4.3266 | Time: 8.78s
# ⏱️ Epoch 123/500 | Disc Loss: 0.0230 | Gen Loss: 4.0206 | Time: 8.36s
# ⏱️ Epoch 124/500 | Disc Loss: 0.0168 | Gen Loss: 4.2603 | Time: 8.97s
# ⏱️ Epoch 125/500 | Disc Loss: 0.0150 | Gen Loss: 4.3976 | Time: 8.67s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 126/500 | Disc Loss: 0.0133 | Gen Loss: 4.5075 | Time: 8.80s
# ⏱️ Epoch 127/500 | Disc Loss: 0.0125 | Gen Loss: 4.6349 | Time: 8.97s
# ⏱️ Epoch 128/500 | Disc Loss: 0.0118 | Gen Loss: 4.6276 | Time: 9.26s
# ⏱️ Epoch 129/500 | Disc Loss: 0.0116 | Gen Loss: 4.6784 | Time: 8.30s
# ⏱️ Epoch 130/500 | Disc Loss: 0.0127 | Gen Loss: 4.6757 | Time: 8.97s
# ⏱️ Epoch 131/500 | Disc Loss: 0.0115 | Gen Loss: 4.7477 | Time: 9.03s
# ⏱️ Epoch 132/500 | Disc Loss: 0.0115 | Gen Loss: 4.7090 | Time: 8.27s
# ⏱️ Epoch 133/500 | Disc Loss: 0.0105 | Gen Loss: 4.7844 | Time: 8.94s
# ⏱️ Epoch 134/500 | Disc Loss: 0.0112 | Gen Loss: 4.7961 | Time: 9.02s
# ⏱️ Epoch 135/500 | Disc Loss: 0.0098 | Gen Loss: 4.8652 | Time: 8.22s
# ⏱️ Epoch 136/500 | Disc Loss: 0.0095 | Gen Loss: 4.9142 | Time: 8.95s
# ⏱️ Epoch 137/500 | Disc Loss: 0.0094 | Gen Loss: 4.8616 | Time: 8.96s
# ⏱️ Epoch 138/500 | Disc Loss: 0.0093 | Gen Loss: 4.9431 | Time: 8.09s
# ⏱️ Epoch 139/500 | Disc Loss: 0.0088 | Gen Loss: 4.9746 | Time: 8.83s
# ⏱️ Epoch 140/500 | Disc Loss: 0.0091 | Gen Loss: 5.0345 | Time: 8.86s
# ⏱️ Epoch 141/500 | Disc Loss: 0.0084 | Gen Loss: 5.0584 | Time: 8.16s
# ⏱️ Epoch 142/500 | Disc Loss: 0.0079 | Gen Loss: 5.1226 | Time: 8.99s
# ⏱️ Epoch 143/500 | Disc Loss: 0.0083 | Gen Loss: 5.0814 | Time: 9.26s
# ⏱️ Epoch 144/500 | Disc Loss: 0.0074 | Gen Loss: 5.1855 | Time: 8.34s
# ⏱️ Epoch 145/500 | Disc Loss: 0.0073 | Gen Loss: 5.2278 | Time: 9.08s
# ⏱️ Epoch 146/500 | Disc Loss: 0.0080 | Gen Loss: 5.2064 | Time: 9.14s
# ⏱️ Epoch 147/500 | Disc Loss: 0.0074 | Gen Loss: 5.2361 | Time: 8.48s
# ⏱️ Epoch 148/500 | Disc Loss: 0.0073 | Gen Loss: 5.2175 | Time: 9.06s
# ⏱️ Epoch 149/500 | Disc Loss: 0.0072 | Gen Loss: 5.3054 | Time: 9.19s
# ⏱️ Epoch 150/500 | Disc Loss: 0.0057 | Gen Loss: 5.3997 | Time: 8.40s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 151/500 | Disc Loss: 0.0064 | Gen Loss: 5.3284 | Time: 9.46s
# ⏱️ Epoch 152/500 | Disc Loss: 0.0060 | Gen Loss: 5.4093 | Time: 8.98s
# ⏱️ Epoch 153/500 | Disc Loss: 0.0061 | Gen Loss: 5.3863 | Time: 8.52s
# ⏱️ Epoch 154/500 | Disc Loss: 0.0058 | Gen Loss: 5.4329 | Time: 8.99s
# ⏱️ Epoch 155/500 | Disc Loss: 0.0055 | Gen Loss: 5.5144 | Time: 9.26s
# ⏱️ Epoch 156/500 | Disc Loss: 0.4266 | Gen Loss: 6.7801 | Time: 9.30s
# ⏱️ Epoch 157/500 | Disc Loss: 0.0815 | Gen Loss: 4.0700 | Time: 8.98s
# ⏱️ Epoch 158/500 | Disc Loss: 0.0271 | Gen Loss: 3.8771 | Time: 9.52s
# ⏱️ Epoch 159/500 | Disc Loss: 0.0199 | Gen Loss: 4.2212 | Time: 9.59s
# ⏱️ Epoch 160/500 | Disc Loss: 0.0518 | Gen Loss: 4.3452 | Time: 9.02s
# ⏱️ Epoch 161/500 | Disc Loss: 0.0153 | Gen Loss: 4.5077 | Time: 9.32s
# ⏱️ Epoch 162/500 | Disc Loss: 0.0115 | Gen Loss: 4.6783 | Time: 9.72s
# ⏱️ Epoch 163/500 | Disc Loss: 0.0098 | Gen Loss: 4.8159 | Time: 9.58s
# ⏱️ Epoch 164/500 | Disc Loss: 0.0088 | Gen Loss: 4.8886 | Time: 9.02s
# ⏱️ Epoch 165/500 | Disc Loss: 0.0081 | Gen Loss: 5.0311 | Time: 9.51s
# ⏱️ Epoch 166/500 | Disc Loss: 0.0071 | Gen Loss: 5.1235 | Time: 9.49s
# ⏱️ Epoch 167/500 | Disc Loss: 0.0069 | Gen Loss: 5.1864 | Time: 9.18s
# ⏱️ Epoch 168/500 | Disc Loss: 0.0064 | Gen Loss: 5.2180 | Time: 9.26s
# ⏱️ Epoch 169/500 | Disc Loss: 0.0065 | Gen Loss: 5.2844 | Time: 9.43s
# ⏱️ Epoch 170/500 | Disc Loss: 0.0065 | Gen Loss: 5.3473 | Time: 9.56s
# ⏱️ Epoch 171/500 | Disc Loss: 0.0062 | Gen Loss: 5.3955 | Time: 9.08s
# ⏱️ Epoch 172/500 | Disc Loss: 0.0056 | Gen Loss: 5.4157 | Time: 9.53s
# ⏱️ Epoch 173/500 | Disc Loss: 0.0056 | Gen Loss: 5.4484 | Time: 9.52s
# ⏱️ Epoch 174/500 | Disc Loss: 0.0054 | Gen Loss: 5.5370 | Time: 9.03s
# ⏱️ Epoch 175/500 | Disc Loss: 0.0061 | Gen Loss: 5.4208 | Time: 9.12s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 176/500 | Disc Loss: 0.0949 | Gen Loss: 5.0257 | Time: 9.99s
# ⏱️ Epoch 177/500 | Disc Loss: 0.0117 | Gen Loss: 4.5935 | Time: 9.43s
# ⏱️ Epoch 178/500 | Disc Loss: 0.0094 | Gen Loss: 4.7982 | Time: 8.92s
# ⏱️ Epoch 179/500 | Disc Loss: 0.0080 | Gen Loss: 5.0153 | Time: 9.28s
# ⏱️ Epoch 180/500 | Disc Loss: 0.0077 | Gen Loss: 5.1040 | Time: 9.38s
# ⏱️ Epoch 181/500 | Disc Loss: 0.0105 | Gen Loss: 5.2479 | Time: 8.84s
# ⏱️ Epoch 182/500 | Disc Loss: 0.0142 | Gen Loss: 5.3509 | Time: 8.79s
# ⏱️ Epoch 183/500 | Disc Loss: 0.0059 | Gen Loss: 5.2475 | Time: 8.97s
# ⏱️ Epoch 184/500 | Disc Loss: 0.0050 | Gen Loss: 5.3632 | Time: 8.53s
# ⏱️ Epoch 185/500 | Disc Loss: 0.0048 | Gen Loss: 5.4943 | Time: 8.64s
# ⏱️ Epoch 186/500 | Disc Loss: 0.0043 | Gen Loss: 5.5981 | Time: 9.05s
# ⏱️ Epoch 187/500 | Disc Loss: 0.0042 | Gen Loss: 5.6933 | Time: 8.48s
# ⏱️ Epoch 188/500 | Disc Loss: 0.0037 | Gen Loss: 5.8078 | Time: 8.33s
# ⏱️ Epoch 189/500 | Disc Loss: 0.0037 | Gen Loss: 5.7641 | Time: 9.02s
# ⏱️ Epoch 190/500 | Disc Loss: 0.0054 | Gen Loss: 5.6390 | Time: 8.39s
# ⏱️ Epoch 191/500 | Disc Loss: 0.0873 | Gen Loss: 5.0274 | Time: 8.60s
# ⏱️ Epoch 192/500 | Disc Loss: 0.0102 | Gen Loss: 4.7504 | Time: 9.23s
# ⏱️ Epoch 193/500 | Disc Loss: 0.0083 | Gen Loss: 4.8912 | Time: 8.86s
# ⏱️ Epoch 194/500 | Disc Loss: 0.0071 | Gen Loss: 5.0299 | Time: 9.00s
# ⏱️ Epoch 195/500 | Disc Loss: 0.0060 | Gen Loss: 5.2408 | Time: 9.39s
# ⏱️ Epoch 196/500 | Disc Loss: 0.0048 | Gen Loss: 5.3842 | Time: 9.60s
# ⏱️ Epoch 197/500 | Disc Loss: 0.0042 | Gen Loss: 5.5815 | Time: 9.02s
# ⏱️ Epoch 198/500 | Disc Loss: 0.0038 | Gen Loss: 5.6260 | Time: 9.31s
# ⏱️ Epoch 199/500 | Disc Loss: 0.0037 | Gen Loss: 5.6970 | Time: 9.23s
# ⏱️ Epoch 200/500 | Disc Loss: 0.0038 | Gen Loss: 5.7851 | Time: 8.63s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 201/500 | Disc Loss: 0.0034 | Gen Loss: 5.8594 | Time: 10.03s
# ⏱️ Epoch 202/500 | Disc Loss: 0.0033 | Gen Loss: 5.8709 | Time: 9.60s
# ⏱️ Epoch 203/500 | Disc Loss: 0.0033 | Gen Loss: 5.8867 | Time: 9.82s
# ⏱️ Epoch 204/500 | Disc Loss: 0.0031 | Gen Loss: 5.9024 | Time: 9.13s
# ⏱️ Epoch 205/500 | Disc Loss: 0.0041 | Gen Loss: 5.8219 | Time: 9.37s
# ⏱️ Epoch 206/500 | Disc Loss: 0.0067 | Gen Loss: 5.9887 | Time: 9.48s
# ⏱️ Epoch 207/500 | Disc Loss: 0.0031 | Gen Loss: 5.8440 | Time: 9.60s
# ⏱️ Epoch 208/500 | Disc Loss: 0.0028 | Gen Loss: 5.9751 | Time: 9.22s
# ⏱️ Epoch 209/500 | Disc Loss: 0.0027 | Gen Loss: 6.0346 | Time: 9.78s
# ⏱️ Epoch 210/500 | Disc Loss: 0.0024 | Gen Loss: 6.1300 | Time: 9.44s
# ⏱️ Epoch 211/500 | Disc Loss: 0.0025 | Gen Loss: 6.1253 | Time: 10.22s
# ⏱️ Epoch 212/500 | Disc Loss: 0.0024 | Gen Loss: 6.1644 | Time: 8.65s
# ⏱️ Epoch 213/500 | Disc Loss: 0.0028 | Gen Loss: 6.2179 | Time: 9.27s
# ⏱️ Epoch 214/500 | Disc Loss: 0.0028 | Gen Loss: 6.2197 | Time: 9.08s
# ⏱️ Epoch 215/500 | Disc Loss: 0.0521 | Gen Loss: 5.6033 | Time: 8.57s
# ⏱️ Epoch 216/500 | Disc Loss: 0.0059 | Gen Loss: 5.4903 | Time: 9.55s
# ⏱️ Epoch 217/500 | Disc Loss: 0.0044 | Gen Loss: 5.6430 | Time: 9.22s
# ⏱️ Epoch 218/500 | Disc Loss: 0.0036 | Gen Loss: 5.8051 | Time: 8.46s
# ⏱️ Epoch 219/500 | Disc Loss: 0.0030 | Gen Loss: 5.9321 | Time: 8.91s
# ⏱️ Epoch 220/500 | Disc Loss: 0.0026 | Gen Loss: 6.0673 | Time: 9.29s
# ⏱️ Epoch 221/500 | Disc Loss: 0.0023 | Gen Loss: 6.1841 | Time: 8.24s
# ⏱️ Epoch 222/500 | Disc Loss: 0.0023 | Gen Loss: 6.2119 | Time: 8.84s
# ⏱️ Epoch 223/500 | Disc Loss: 0.0021 | Gen Loss: 6.2062 | Time: 9.09s
# ⏱️ Epoch 224/500 | Disc Loss: 0.0026 | Gen Loss: 6.2987 | Time: 8.49s
# ⏱️ Epoch 225/500 | Disc Loss: 0.0022 | Gen Loss: 6.2553 | Time: 9.03s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 226/500 | Disc Loss: 0.0020 | Gen Loss: 6.3718 | Time: 9.95s
# ⏱️ Epoch 227/500 | Disc Loss: 0.0019 | Gen Loss: 6.3990 | Time: 8.69s
# ⏱️ Epoch 228/500 | Disc Loss: 0.0018 | Gen Loss: 6.4547 | Time: 8.71s
# ⏱️ Epoch 229/500 | Disc Loss: 0.0017 | Gen Loss: 6.5087 | Time: 9.52s
# ⏱️ Epoch 230/500 | Disc Loss: 0.0018 | Gen Loss: 6.5421 | Time: 9.10s
# ⏱️ Epoch 231/500 | Disc Loss: 0.0016 | Gen Loss: 6.5667 | Time: 8.56s
# ⏱️ Epoch 232/500 | Disc Loss: 0.0016 | Gen Loss: 6.6671 | Time: 9.05s
# ⏱️ Epoch 233/500 | Disc Loss: 0.0014 | Gen Loss: 6.6209 | Time: 9.30s
# ⏱️ Epoch 234/500 | Disc Loss: 0.0015 | Gen Loss: 6.6770 | Time: 8.77s
# ⏱️ Epoch 235/500 | Disc Loss: 0.0015 | Gen Loss: 6.6921 | Time: 9.16s
# ⏱️ Epoch 236/500 | Disc Loss: 0.0018 | Gen Loss: 6.6172 | Time: 9.24s
# ⏱️ Epoch 237/500 | Disc Loss: 0.0016 | Gen Loss: 6.6735 | Time: 8.59s
# ⏱️ Epoch 238/500 | Disc Loss: 0.0017 | Gen Loss: 6.7321 | Time: 9.01s
# ⏱️ Epoch 239/500 | Disc Loss: 0.0017 | Gen Loss: 6.6626 | Time: 9.17s
# ⏱️ Epoch 240/500 | Disc Loss: 0.0014 | Gen Loss: 6.8040 | Time: 8.51s
# ⏱️ Epoch 241/500 | Disc Loss: 0.0015 | Gen Loss: 6.7332 | Time: 8.53s
# ⏱️ Epoch 242/500 | Disc Loss: 0.0013 | Gen Loss: 6.7967 | Time: 9.24s
# ⏱️ Epoch 243/500 | Disc Loss: 0.0013 | Gen Loss: 6.8287 | Time: 8.80s
# ⏱️ Epoch 244/500 | Disc Loss: 0.0013 | Gen Loss: 6.8561 | Time: 9.09s
# ⏱️ Epoch 245/500 | Disc Loss: 0.0012 | Gen Loss: 6.9322 | Time: 9.36s
# ⏱️ Epoch 246/500 | Disc Loss: 0.0014 | Gen Loss: 6.9028 | Time: 9.47s
# ⏱️ Epoch 247/500 | Disc Loss: 0.0010 | Gen Loss: 6.9839 | Time: 8.92s
# ⏱️ Epoch 248/500 | Disc Loss: 0.0012 | Gen Loss: 6.9984 | Time: 9.35s
# ⏱️ Epoch 249/500 | Disc Loss: 0.0011 | Gen Loss: 7.0053 | Time: 9.23s
# ⏱️ Epoch 250/500 | Disc Loss: 0.0010 | Gen Loss: 7.0571 | Time: 10.22s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 251/500 | Disc Loss: 0.0013 | Gen Loss: 7.0263 | Time: 9.20s
# ⏱️ Epoch 252/500 | Disc Loss: 0.0014 | Gen Loss: 7.0505 | Time: 9.36s
# ⏱️ Epoch 253/500 | Disc Loss: 0.0010 | Gen Loss: 7.0291 | Time: 9.28s
# ⏱️ Epoch 254/500 | Disc Loss: 0.0011 | Gen Loss: 7.1320 | Time: 8.51s
# ⏱️ Epoch 255/500 | Disc Loss: 0.0012 | Gen Loss: 7.0478 | Time: 9.37s
# ⏱️ Epoch 256/500 | Disc Loss: 0.0010 | Gen Loss: 7.0521 | Time: 9.40s
# ⏱️ Epoch 257/500 | Disc Loss: 0.0012 | Gen Loss: 7.1360 | Time: 8.93s
# ⏱️ Epoch 258/500 | Disc Loss: 0.0010 | Gen Loss: 7.0989 | Time: 8.95s
# ⏱️ Epoch 259/500 | Disc Loss: 0.0010 | Gen Loss: 7.1748 | Time: 9.40s
# ⏱️ Epoch 260/500 | Disc Loss: 0.0011 | Gen Loss: 7.2047 | Time: 8.85s
# ⏱️ Epoch 261/500 | Disc Loss: 0.0009 | Gen Loss: 7.2264 | Time: 8.48s
# ⏱️ Epoch 262/500 | Disc Loss: 0.0010 | Gen Loss: 7.2010 | Time: 9.14s
# ⏱️ Epoch 263/500 | Disc Loss: 0.0009 | Gen Loss: 7.2444 | Time: 9.32s
# ⏱️ Epoch 264/500 | Disc Loss: 0.0008 | Gen Loss: 7.3204 | Time: 8.50s
# ⏱️ Epoch 265/500 | Disc Loss: 0.0007 | Gen Loss: 7.5000 | Time: 9.89s
# ⏱️ Epoch 266/500 | Disc Loss: 0.0010 | Gen Loss: 7.6058 | Time: 9.56s
# ⏱️ Epoch 267/500 | Disc Loss: 0.0009 | Gen Loss: 7.4774 | Time: 8.88s
# ⏱️ Epoch 268/500 | Disc Loss: 0.0011 | Gen Loss: 7.5158 | Time: 9.00s
# ⏱️ Epoch 269/500 | Disc Loss: 0.0008 | Gen Loss: 7.4126 | Time: 9.17s
# ⏱️ Epoch 270/500 | Disc Loss: 0.0006 | Gen Loss: 7.5236 | Time: 8.73s
# ⏱️ Epoch 271/500 | Disc Loss: 0.0007 | Gen Loss: 7.5487 | Time: 8.72s
# ⏱️ Epoch 272/500 | Disc Loss: 0.0007 | Gen Loss: 7.6589 | Time: 9.23s
# ⏱️ Epoch 273/500 | Disc Loss: 0.0012 | Gen Loss: 7.5573 | Time: 8.68s
# ⏱️ Epoch 274/500 | Disc Loss: 0.0007 | Gen Loss: 7.4857 | Time: 8.22s
# ⏱️ Epoch 275/500 | Disc Loss: 0.0007 | Gen Loss: 7.5115 | Time: 8.95s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 276/500 | Disc Loss: 0.0006 | Gen Loss: 7.6438 | Time: 9.56s
# ⏱️ Epoch 277/500 | Disc Loss: 0.0007 | Gen Loss: 7.6759 | Time: 9.04s
# ⏱️ Epoch 278/500 | Disc Loss: 0.0006 | Gen Loss: 7.6289 | Time: 9.82s
# ⏱️ Epoch 279/500 | Disc Loss: 0.0007 | Gen Loss: 7.6693 | Time: 9.46s
# ⏱️ Epoch 280/500 | Disc Loss: 0.0005 | Gen Loss: 7.7189 | Time: 9.02s
# ⏱️ Epoch 281/500 | Disc Loss: 0.6952 | Gen Loss: 10.5171 | Time: 8.99s
# ⏱️ Epoch 282/500 | Disc Loss: 0.3288 | Gen Loss: 6.4955 | Time: 9.24s
# ⏱️ Epoch 283/500 | Disc Loss: 0.0415 | Gen Loss: 4.0209 | Time: 8.85s
# ⏱️ Epoch 284/500 | Disc Loss: 0.0239 | Gen Loss: 4.1072 | Time: 8.66s
# ⏱️ Epoch 285/500 | Disc Loss: 0.0170 | Gen Loss: 4.3571 | Time: 9.13s
# ⏱️ Epoch 286/500 | Disc Loss: 0.0133 | Gen Loss: 4.6013 | Time: 8.87s
# ⏱️ Epoch 287/500 | Disc Loss: 0.0110 | Gen Loss: 4.6944 | Time: 8.46s
# ⏱️ Epoch 288/500 | Disc Loss: 0.0093 | Gen Loss: 4.8493 | Time: 9.00s
# ⏱️ Epoch 289/500 | Disc Loss: 0.0080 | Gen Loss: 4.9728 | Time: 9.14s
# ⏱️ Epoch 290/500 | Disc Loss: 0.0067 | Gen Loss: 5.1442 | Time: 8.15s
# ⏱️ Epoch 291/500 | Disc Loss: 0.0067 | Gen Loss: 5.1143 | Time: 8.89s
# ⏱️ Epoch 292/500 | Disc Loss: 0.0064 | Gen Loss: 5.2149 | Time: 8.84s
# ⏱️ Epoch 293/500 | Disc Loss: 0.0060 | Gen Loss: 5.3256 | Time: 8.11s
# ⏱️ Epoch 294/500 | Disc Loss: 0.0052 | Gen Loss: 5.3967 | Time: 9.00s
# ⏱️ Epoch 295/500 | Disc Loss: 0.0047 | Gen Loss: 5.5019 | Time: 8.90s
# ⏱️ Epoch 296/500 | Disc Loss: 0.0056 | Gen Loss: 5.6303 | Time: 8.31s
# ⏱️ Epoch 297/500 | Disc Loss: 0.0892 | Gen Loss: 5.7391 | Time: 9.10s
# ⏱️ Epoch 298/500 | Disc Loss: 0.0080 | Gen Loss: 5.0138 | Time: 9.42s
# ⏱️ Epoch 299/500 | Disc Loss: 0.0061 | Gen Loss: 5.1593 | Time: 8.96s
# ⏱️ Epoch 300/500 | Disc Loss: 0.0053 | Gen Loss: 5.2475 | Time: 9.31s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 301/500 | Disc Loss: 0.0050 | Gen Loss: 5.3099 | Time: 9.82s
# ⏱️ Epoch 302/500 | Disc Loss: 0.0044 | Gen Loss: 5.4167 | Time: 8.61s
# ⏱️ Epoch 303/500 | Disc Loss: 0.0040 | Gen Loss: 5.5693 | Time: 8.61s
# ⏱️ Epoch 304/500 | Disc Loss: 0.0037 | Gen Loss: 5.6319 | Time: 8.90s
# ⏱️ Epoch 305/500 | Disc Loss: 0.0033 | Gen Loss: 5.7518 | Time: 8.26s
# ⏱️ Epoch 306/500 | Disc Loss: 0.0037 | Gen Loss: 5.8859 | Time: 8.47s
# ⏱️ Epoch 307/500 | Disc Loss: 0.0050 | Gen Loss: 6.0876 | Time: 9.01s
# ⏱️ Epoch 308/500 | Disc Loss: 0.0026 | Gen Loss: 6.0099 | Time: 8.55s
# ⏱️ Epoch 309/500 | Disc Loss: 0.0022 | Gen Loss: 6.1158 | Time: 8.82s
# ⏱️ Epoch 310/500 | Disc Loss: 0.0021 | Gen Loss: 6.1378 | Time: 9.12s
# ⏱️ Epoch 311/500 | Disc Loss: 0.0022 | Gen Loss: 6.1564 | Time: 9.05s
# ⏱️ Epoch 312/500 | Disc Loss: 0.0020 | Gen Loss: 6.2515 | Time: 8.81s
# ⏱️ Epoch 313/500 | Disc Loss: 0.0019 | Gen Loss: 6.2902 | Time: 9.41s
# ⏱️ Epoch 314/500 | Disc Loss: 0.0020 | Gen Loss: 6.3097 | Time: 9.11s
# ⏱️ Epoch 315/500 | Disc Loss: 0.0019 | Gen Loss: 6.3363 | Time: 8.53s
# ⏱️ Epoch 316/500 | Disc Loss: 0.0019 | Gen Loss: 6.3916 | Time: 9.39s
# ⏱️ Epoch 317/500 | Disc Loss: 0.0018 | Gen Loss: 6.4193 | Time: 9.38s
# ⏱️ Epoch 318/500 | Disc Loss: 0.0019 | Gen Loss: 6.4089 | Time: 8.87s
# ⏱️ Epoch 319/500 | Disc Loss: 0.0019 | Gen Loss: 6.3448 | Time: 9.14s
# ⏱️ Epoch 320/500 | Disc Loss: 0.0017 | Gen Loss: 6.4473 | Time: 9.24s
# ⏱️ Epoch 321/500 | Disc Loss: 0.0016 | Gen Loss: 6.5654 | Time: 9.12s
# ⏱️ Epoch 322/500 | Disc Loss: 0.0017 | Gen Loss: 6.6126 | Time: 9.16s
# ⏱️ Epoch 323/500 | Disc Loss: 0.0015 | Gen Loss: 6.6667 | Time: 9.30s
# ⏱️ Epoch 324/500 | Disc Loss: 0.0013 | Gen Loss: 6.7051 | Time: 9.57s
# ⏱️ Epoch 325/500 | Disc Loss: 0.0012 | Gen Loss: 6.8218 | Time: 8.96s
# ✅ Saved outputs to /content/drive/MyDrive/ViTGAN_outputs
# ⏱️ Epoch 326/500 | Disc Loss: 0.0012 | Gen Loss: 6.8084 | Time: 9.82s
# ⏱️ Epoch 327/500 | Disc Loss: 0.0012 | Gen Loss: 6.8564 | Time: 9.10s
# ⏱️ Epoch 328/500 | Disc Loss: 0.0011 | Gen Loss: 6.9305 | Time: 8.60s
# ⏱️ Epoch 329/500 | Disc Loss: 0.0012 | Gen Loss: 6.8824 | Time: 8.86s
# ⏱️ Epoch 330/500 | Disc Loss: 0.0011 | Gen Loss: 6.9622 | Time: 8.99s
# ⏱️ Epoch 331/500 | Disc Loss: 0.0012 | Gen Loss: 6.9483 | Time: 8.51s
# ⏱️ Epoch 332/500 | Disc Loss: 0.0012 | Gen Loss: 6.9691 | Time: 8.88s
# ⏱️ Epoch 333/500 | Disc Loss: 0.0011 | Gen Loss: 7.0362 | Time: 9.25s
# ⏱️ Epoch 334/500 | Disc Loss: 0.0010 | Gen Loss: 7.0278 | Time: 10.22s
# ⏱️ Epoch 335/500 | Disc Loss: 0.0009 | Gen Loss: 7.1254 | Time: 8.52s
# ⏱️ Epoch 336/500 | Disc Loss: 0.0010 | Gen Loss: 7.1680 | Time: 9.04s
# ⏱️ Epoch 337/500 | Disc Loss: 0.0009 | Gen Loss: 7.1249 | Time: 9.19s
